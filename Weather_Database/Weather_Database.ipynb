# %%
#Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import the citipy module
from citipy import citipy

#Import the datetime module from the datetime library
from datetime import datetime

# %%
# Generate a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes in a list
coordinates = list(lats_lngs)

# %%
#Create a list for holding the names of cities
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i>=50):
        set_count += 1
        record_count = 1
#         time.sleep(60)
        
    #Create endpoint url for each city.
    city_url = url + "&q=" + city
        
    #log the url,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
    #Add 1 to the record count.
    record_count += 1
        
    #Run an API request for each of the cities.
    try:
         #Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #Rain data
        try:
            city_rain = city_weather["rain"]["3h"]
            
        except:
            city_rain = 0.00 
            
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0.00
            
            
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,                                                         
                             "Current Description":city_weather_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#Indicate the data loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | umm kaddadah
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | kitimat
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | mapua
# Processing Record 9 of Set 1 | coihueco
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | vila franca do campo
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | payson
# Processing Record 16 of Set 1 | abalak
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | yumen
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | klaksvik
# Processing Record 23 of Set 1 | calvia
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | maniitsoq
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | dorchester
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | trinidad
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | tawau
# Processing Record 34 of Set 1 | solnechnyy
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | ulladulla
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | ramon castilla
# Processing Record 46 of Set 1 | ambon
# Processing Record 47 of Set 1 | boyolangu
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | nouadhibou
# Processing Record 4 of Set 2 | hirara
# Processing Record 5 of Set 2 | iquitos
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 2 | tual
# Processing Record 10 of Set 2 | tazovskiy
# Processing Record 11 of Set 2 | banjar
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 2 | georgetown
# Processing Record 16 of Set 2 | deputatskiy
# Processing Record 17 of Set 2 | terney
# Processing Record 18 of Set 2 | fulacunda
# City not found. Skipping...
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | victor harbor
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | doume
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | sept-iles
# Processing Record 27 of Set 2 | waiuku
# Processing Record 28 of Set 2 | los llanos de aridane
# Processing Record 29 of Set 2 | anshun
# Processing Record 30 of Set 2 | coari
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 2 | kavaratti
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | arvin
# Processing Record 39 of Set 2 | ouesso
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | abomsa
# Processing Record 42 of Set 2 | dudinka
# Processing Record 43 of Set 2 | bristol
# Processing Record 44 of Set 2 | la ronge
# Processing Record 45 of Set 2 | lazaro cardenas
# Processing Record 46 of Set 2 | maragogi
# Processing Record 47 of Set 2 | lasem
# Processing Record 48 of Set 2 | namikupa
# Processing Record 49 of Set 2 | ilulissat
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | rikitea
# Processing Record 2 of Set 3 | peniche
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | norman wells
# Processing Record 5 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 7 of Set 3 | shangrao
# Processing Record 8 of Set 3 | saint-pie
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | lahij
# Processing Record 11 of Set 3 | zhigansk
# Processing Record 12 of Set 3 | necochea
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | alice springs
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | namibe
# Processing Record 18 of Set 3 | salinas
# Processing Record 19 of Set 3 | chulman
# Processing Record 20 of Set 3 | jieshi
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | manama
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | port hedland
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | paamiut
# Processing Record 27 of Set 3 | slave lake
# Processing Record 28 of Set 3 | pevek
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | cape town
# Processing Record 31 of Set 3 | grindavik
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | gladstone
# Processing Record 34 of Set 3 | synya
# Processing Record 35 of Set 3 | abha
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | progreso
# Processing Record 40 of Set 3 | tuatapere
# Processing Record 41 of Set 3 | sechura
# Processing Record 42 of Set 3 | hambantota
# Processing Record 43 of Set 3 | port-cartier
# Processing Record 44 of Set 3 | iqaluit
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | walvis bay
# Processing Record 47 of Set 3 | port-gentil
# Processing Record 48 of Set 3 | santiago del estero
# Processing Record 49 of Set 3 | ixtapa
# Processing Record 50 of Set 3 | ballinasloe
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | iskandar
# Processing Record 3 of Set 4 | burnie
# Processing Record 4 of Set 4 | komsomolskiy
# Processing Record 5 of Set 4 | fort nelson
# Processing Record 6 of Set 4 | rockport
# Processing Record 7 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 8 of Set 4 | adrar
# Processing Record 9 of Set 4 | fairfield
# Processing Record 10 of Set 4 | berck
# Processing Record 11 of Set 4 | raudeberg
# Processing Record 12 of Set 4 | araceli
# Processing Record 13 of Set 4 | kazachinskoye
# Processing Record 14 of Set 4 | valparaiso
# Processing Record 15 of Set 4 | sao paulo de olivenca
# Processing Record 16 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 4 | qasigiannguit
# Processing Record 18 of Set 4 | ak-dovurak
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | preeceville
# Processing Record 21 of Set 4 | tuktoyaktuk
# Processing Record 22 of Set 4 | jaru
# Processing Record 23 of Set 4 | metu
# Processing Record 24 of Set 4 | coquimbo
# Processing Record 25 of Set 4 | dese
# Processing Record 26 of Set 4 | noumea
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | inhambane
# Processing Record 29 of Set 4 | carnarvon
# Processing Record 30 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | hami
# Processing Record 33 of Set 4 | cordoba
# Processing Record 34 of Set 4 | fare
# Processing Record 35 of Set 4 | wilmington
# Processing Record 36 of Set 4 | vuktyl
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | skjervoy
# Processing Record 39 of Set 4 | korla
# Processing Record 40 of Set 4 | avera
# Processing Record 41 of Set 4 | port lincoln
# Processing Record 42 of Set 4 | alexandria
# Processing Record 43 of Set 4 | kirksville
# Processing Record 44 of Set 4 | campbell river
# Processing Record 45 of Set 4 | araouane
# Processing Record 46 of Set 4 | tromso
# Processing Record 47 of Set 4 | fairbanks
# Processing Record 48 of Set 4 | ukiah
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | sitka
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | qaanaaq
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | margate
# Processing Record 5 of Set 5 | poum
# Processing Record 6 of Set 5 | furth im wald
# Processing Record 7 of Set 5 | dikson
# Processing Record 8 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | boa vista
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | monrovia
# Processing Record 13 of Set 5 | huarmey
# Processing Record 14 of Set 5 | berezovyy
# Processing Record 15 of Set 5 | muscat
# Processing Record 16 of Set 5 | gravdal
# Processing Record 17 of Set 5 | acapulco
# Processing Record 18 of Set 5 | mareeba
# Processing Record 19 of Set 5 | segbwema
# Processing Record 20 of Set 5 | mabopane
# Processing Record 21 of Set 5 | carballo
# Processing Record 22 of Set 5 | vilyuysk
# Processing Record 23 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 24 of Set 5 | malindi
# Processing Record 25 of Set 5 | vao
# Processing Record 26 of Set 5 | san lazaro
# Processing Record 27 of Set 5 | toamasina
# Processing Record 28 of Set 5 | gimli
# Processing Record 29 of Set 5 | port shepstone
# Processing Record 30 of Set 5 | vinh
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | kloulklubed
# Processing Record 33 of Set 5 | sirumugai
# Processing Record 34 of Set 5 | salvador
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | tiznit
# Processing Record 37 of Set 5 | evensk
# Processing Record 38 of Set 5 | shenjiamen
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | florianopolis
# Processing Record 41 of Set 5 | siniscola
# Processing Record 42 of Set 5 | smithers
# Processing Record 43 of Set 5 | wanning
# Processing Record 44 of Set 5 | rio grande
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | mar del plata
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | inuvik
# Processing Record 50 of Set 5 | mocuba
# Processing Record 1 of Set 6 | zeya
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | hualmay
# Processing Record 4 of Set 6 | grand gaube
# Processing Record 5 of Set 6 | abrau-dyurso
# Processing Record 6 of Set 6 | mackay
# Processing Record 7 of Set 6 | irshava
# Processing Record 8 of Set 6 | wanaka
# Processing Record 9 of Set 6 | llandrindod wells
# Processing Record 10 of Set 6 | yichun
# Processing Record 11 of Set 6 | wyndham
# Processing Record 12 of Set 6 | ljubinje
# Processing Record 13 of Set 6 | bereda
# Processing Record 14 of Set 6 | athabasca
# Processing Record 15 of Set 6 | ginir
# Processing Record 16 of Set 6 | kaifeng
# Processing Record 17 of Set 6 | bathsheba
# Processing Record 18 of Set 6 | naze
# Processing Record 19 of Set 6 | parana
# Processing Record 20 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 6 | katsuura
# Processing Record 22 of Set 6 | le port
# Processing Record 23 of Set 6 | devonport
# Processing Record 24 of Set 6 | laakirchen
# Processing Record 25 of Set 6 | lotoshino
# Processing Record 26 of Set 6 | provideniya
# Processing Record 27 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 28 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 6 | kochevo
# Processing Record 30 of Set 6 | boden
# Processing Record 31 of Set 6 | whitianga
# Processing Record 32 of Set 6 | beeville
# Processing Record 33 of Set 6 | leeton
# Processing Record 34 of Set 6 | tabuk
# Processing Record 35 of Set 6 | clyde
# Processing Record 36 of Set 6 | nantucket
# Processing Record 37 of Set 6 | farah
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | moorhead
# Processing Record 40 of Set 6 | san carlos de bariloche
# Processing Record 41 of Set 6 | saint george
# Processing Record 42 of Set 6 | kungurtug
# Processing Record 43 of Set 6 | sur
# Processing Record 44 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 6 | kjopsvik
# Processing Record 46 of Set 6 | kota tinggi
# Processing Record 47 of Set 6 | ler
# Processing Record 48 of Set 6 | yellowknife
# Processing Record 49 of Set 6 | mollendo
# Processing Record 50 of Set 6 | alta floresta
# Processing Record 1 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 2 of Set 7 | mayo
# Processing Record 3 of Set 7 | samarai
# Processing Record 4 of Set 7 | neyshabur
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | bengkulu
# Processing Record 7 of Set 7 | kushiro
# Processing Record 8 of Set 7 | manono
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | bad kreuznach
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | hobyo
# Processing Record 13 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 7 | havre-saint-pierre
# Processing Record 15 of Set 7 | lithakia
# Processing Record 16 of Set 7 | auki
# Processing Record 17 of Set 7 | aklavik
# Processing Record 18 of Set 7 | blagoyevo
# Processing Record 19 of Set 7 | ondangwa
# Processing Record 20 of Set 7 | shahrud
# Processing Record 21 of Set 7 | athens
# Processing Record 22 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 7 | parsons
# Processing Record 24 of Set 7 | moa
# Processing Record 25 of Set 7 | port augusta
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | tonekabon
# Processing Record 28 of Set 7 | sakakah
# Processing Record 29 of Set 7 | sistranda
# Processing Record 30 of Set 7 | ban nahin
# Processing Record 31 of Set 7 | oga
# Processing Record 32 of Set 7 | bodden town
# Processing Record 33 of Set 7 | dzaoudzi
# Processing Record 34 of Set 7 | chokurdakh
# Processing Record 35 of Set 7 | honiara
# Processing Record 36 of Set 7 | manado
# Processing Record 37 of Set 7 | comodoro rivadavia
# Processing Record 38 of Set 7 | raga
# Processing Record 39 of Set 7 | shimoda
# Processing Record 40 of Set 7 | thilogne
# City not found. Skipping...
# Processing Record 41 of Set 7 | high level
# Processing Record 42 of Set 7 | torbay
# Processing Record 43 of Set 7 | andros town
# Processing Record 44 of Set 7 | sarangani
# Processing Record 45 of Set 7 | yar-sale
# Processing Record 46 of Set 7 | oranjemund
# Processing Record 47 of Set 7 | clyde river
# Processing Record 48 of Set 7 | kati
# Processing Record 49 of Set 7 | yatou
# Processing Record 50 of Set 7 | potam
# Processing Record 1 of Set 8 | omboue
# Processing Record 2 of Set 8 | tafresh
# Processing Record 3 of Set 8 | abu dhabi
# Processing Record 4 of Set 8 | cardston
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | port elizabeth
# Processing Record 7 of Set 8 | sal rei
# Processing Record 8 of Set 8 | sorland
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | mathbaria
# Processing Record 11 of Set 8 | sabha
# Processing Record 12 of Set 8 | aden
# Processing Record 13 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 8 | asfi
# Processing Record 15 of Set 8 | lake havasu city
# Processing Record 16 of Set 8 | moi
# Processing Record 17 of Set 8 | togur
# Processing Record 18 of Set 8 | mehamn
# Processing Record 19 of Set 8 | luanda
# Processing Record 20 of Set 8 | bulancak
# Processing Record 21 of Set 8 | pyaozerskiy
# Processing Record 22 of Set 8 | shubarkuduk
# Processing Record 23 of Set 8 | waddan
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | chebsara
# Processing Record 26 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 27 of Set 8 | mokhsogollokh
# Processing Record 28 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 8 | shitkino
# Processing Record 30 of Set 8 | leningradskiy
# Processing Record 31 of Set 8 | otukpo
# Processing Record 32 of Set 8 | zyryanka
# Processing Record 33 of Set 8 | zharkent
# Processing Record 34 of Set 8 | san luis
# Processing Record 35 of Set 8 | san patricio
# Processing Record 36 of Set 8 | xinzhi
# Processing Record 37 of Set 8 | suffolk
# Processing Record 38 of Set 8 | muros
# Processing Record 39 of Set 8 | isangel
# Processing Record 40 of Set 8 | pathein
# Processing Record 41 of Set 8 | kochi
# Processing Record 42 of Set 8 | prince rupert
# Processing Record 43 of Set 8 | teya
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | ambilobe
# Processing Record 46 of Set 8 | salto
# Processing Record 47 of Set 8 | mayor pablo lagerenza
# Processing Record 48 of Set 8 | lagoa
# Processing Record 49 of Set 8 | caravelas
# Processing Record 50 of Set 8 | touros
# Processing Record 1 of Set 9 | kashi
# Processing Record 2 of Set 9 | pilar
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | sesheke
# Processing Record 5 of Set 9 | santa fe
# Processing Record 6 of Set 9 | padang
# Processing Record 7 of Set 9 | kananga
# Processing Record 8 of Set 9 | kahului
# Processing Record 9 of Set 9 | vanino
# Processing Record 10 of Set 9 | wewak
# Processing Record 11 of Set 9 | tartus
# Processing Record 12 of Set 9 | san jose
# Processing Record 13 of Set 9 | pangody
# Processing Record 14 of Set 9 | russellville
# Processing Record 15 of Set 9 | saint-francois
# Processing Record 16 of Set 9 | saint anthony
# Processing Record 17 of Set 9 | cururupu
# Processing Record 18 of Set 9 | victoria
# Processing Record 19 of Set 9 | wanlaweyn
# Processing Record 20 of Set 9 | teguise
# Processing Record 21 of Set 9 | nishihara
# Processing Record 22 of Set 9 | kalmunai
# Processing Record 23 of Set 9 | linjiang
# Processing Record 24 of Set 9 | merauke
# Processing Record 25 of Set 9 | vestmannaeyjar
# Processing Record 26 of Set 9 | bougouni
# Processing Record 27 of Set 9 | knysna
# Processing Record 28 of Set 9 | kulhudhuffushi
# Processing Record 29 of Set 9 | dawlatabad
# Processing Record 30 of Set 9 | parangan
# Processing Record 31 of Set 9 | prado
# Processing Record 32 of Set 9 | altoona
# Processing Record 33 of Set 9 | dale
# Processing Record 34 of Set 9 | kampot
# Processing Record 35 of Set 9 | sosnovo-ozerskoye
# Processing Record 36 of Set 9 | darbhanga
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | bogotol
# Processing Record 39 of Set 9 | lima
# Processing Record 40 of Set 9 | stykkisholmur
# Processing Record 41 of Set 9 | grand-santi
# Processing Record 42 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 9 | warangal
# Processing Record 44 of Set 9 | omaruru
# Processing Record 45 of Set 9 | sisimiut
# Processing Record 46 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 47 of Set 9 | russell
# Processing Record 48 of Set 9 | pangoa
# Processing Record 49 of Set 9 | moree
# Processing Record 50 of Set 9 | rocha
# Processing Record 1 of Set 10 | katherine
# Processing Record 2 of Set 10 | te anau
# Processing Record 3 of Set 10 | zhezkazgan
# Processing Record 4 of Set 10 | santa rosalia
# Processing Record 5 of Set 10 | aiken
# Processing Record 6 of Set 10 | bhakkar
# Processing Record 7 of Set 10 | cervo
# Processing Record 8 of Set 10 | pangkalanbuun
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | wenling
# Processing Record 11 of Set 10 | north bend
# Processing Record 12 of Set 10 | lamu
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | muswellbrook
# Processing Record 15 of Set 10 | jodhpur
# Processing Record 16 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 10 | shahreza
# Processing Record 18 of Set 10 | newport
# Processing Record 19 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 10 | puerto maldonado
# Processing Record 21 of Set 10 | balaipungut
# Processing Record 22 of Set 10 | suez
# Processing Record 23 of Set 10 | tinde
# Processing Record 24 of Set 10 | sao miguel do araguaia
# Processing Record 25 of Set 10 | sambalpur
# Processing Record 26 of Set 10 | kanakapura
# Processing Record 27 of Set 10 | jacqueville
# Processing Record 28 of Set 10 | kalevala
# Processing Record 29 of Set 10 | payakumbuh
# Processing Record 30 of Set 10 | vaitape
# Processing Record 31 of Set 10 | guerrero negro
# Processing Record 32 of Set 10 | sangar
# Processing Record 33 of Set 10 | harper
# Processing Record 34 of Set 10 | shymkent
# Processing Record 35 of Set 10 | pochutla
# Processing Record 36 of Set 10 | mae ramat
# Processing Record 37 of Set 10 | ofunato
# Processing Record 38 of Set 10 | savannah bight
# Processing Record 39 of Set 10 | luwuk
# Processing Record 40 of Set 10 | yerbogachen
# Processing Record 41 of Set 10 | beloha
# Processing Record 42 of Set 10 | mount gambier
# Processing Record 43 of Set 10 | mahon
# Processing Record 44 of Set 10 | dong hoi
# Processing Record 45 of Set 10 | champerico
# Processing Record 46 of Set 10 | dongdu
# Processing Record 47 of Set 10 | huanan
# Processing Record 48 of Set 10 | waipawa
# Processing Record 49 of Set 10 | churapcha
# Processing Record 50 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 11 | pampas
# Processing Record 2 of Set 11 | veraval
# Processing Record 3 of Set 11 | neuquen
# Processing Record 4 of Set 11 | jacareacanga
# Processing Record 5 of Set 11 | tessalit
# Processing Record 6 of Set 11 | katobu
# Processing Record 7 of Set 11 | camacha
# Processing Record 8 of Set 11 | mariental
# Processing Record 9 of Set 11 | marsh harbour
# Processing Record 10 of Set 11 | ruidoso
# Processing Record 11 of Set 11 | bongandanga
# Processing Record 12 of Set 11 | takoradi
# Processing Record 13 of Set 11 | hokitika
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | lompoc
# Processing Record 16 of Set 11 | ilula
# Processing Record 17 of Set 11 | paoua
# Processing Record 18 of Set 11 | annau
# Processing Record 19 of Set 11 | tursunzoda
# Processing Record 20 of Set 11 | dingle
# Processing Record 21 of Set 11 | ismailia
# Processing Record 22 of Set 11 | belaya gora
# Processing Record 23 of Set 11 | pangai
# Processing Record 24 of Set 11 | alyangula
# Processing Record 25 of Set 11 | zigong
# Processing Record 26 of Set 11 | las juntas
# Processing Record 27 of Set 11 | kachug
# Processing Record 28 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 29 of Set 11 | pisco
# Processing Record 30 of Set 11 | tarakan
# Processing Record 31 of Set 11 | bardiyah
# Processing Record 32 of Set 11 | rawson
# Processing Record 33 of Set 11 | tezu
# Processing Record 34 of Set 11 | tinskoy
# Processing Record 35 of Set 11 | vanimo
# Processing Record 36 of Set 11 | araripe
# Processing Record 37 of Set 11 | tambura
# Processing Record 38 of Set 11 | hasaki
# Processing Record 39 of Set 11 | partizanskoye
# Processing Record 40 of Set 11 | goderich
# Processing Record 41 of Set 11 | saint-joseph
# Processing Record 42 of Set 11 | novaya mayna
# Processing Record 43 of Set 11 | san jeronimo
# Processing Record 44 of Set 11 | beringovskiy
# Processing Record 45 of Set 11 | kaithal
# Processing Record 46 of Set 11 | brest
# Processing Record 47 of Set 11 | benguela
# Processing Record 48 of Set 11 | sobolevo
# Processing Record 49 of Set 11 | huaura
# Processing Record 50 of Set 11 | geraldton
# Processing Record 1 of Set 12 | minab
# Processing Record 2 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | san juan
# Processing Record 5 of Set 12 | coahuayana
# Processing Record 6 of Set 12 | zhangye
# Processing Record 7 of Set 12 | tuy hoa
# Processing Record 8 of Set 12 | abonnema
# Processing Record 9 of Set 12 | aniva
# Processing Record 10 of Set 12 | sola
# Processing Record 11 of Set 12 | jalu
# Processing Record 12 of Set 12 | balkhash
# Processing Record 13 of Set 12 | mitu
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 16 of Set 12 | san quintin
# Processing Record 17 of Set 12 | west wendover
# Processing Record 18 of Set 12 | methoni
# Processing Record 19 of Set 12 | manzhouli
# Processing Record 20 of Set 12 | tautira
# Processing Record 21 of Set 12 | artyom
# Processing Record 22 of Set 12 | rudnichnyy
# Processing Record 23 of Set 12 | kenai
# Processing Record 24 of Set 12 | zanjan
# Processing Record 25 of Set 12 | sao jose da coroa grande
# Processing Record 26 of Set 12 | kilrush
# Processing Record 27 of Set 12 | itarema
# Processing Record 28 of Set 12 | buraydah
# Processing Record 29 of Set 12 | mingshui
# Processing Record 30 of Set 12 | yambio
# Processing Record 31 of Set 12 | baracoa
# Processing Record 32 of Set 12 | moscow
# Processing Record 33 of Set 12 | taltal
# Processing Record 34 of Set 12 | liwale
# Processing Record 35 of Set 12 | muravlenko
# Processing Record 36 of Set 12 | pampa
# Processing Record 37 of Set 12 | rosignol
# Processing Record 38 of Set 12 | sidney
# Processing Record 39 of Set 12 | mahina
# Processing Record 40 of Set 12 | voh
# Processing Record 41 of Set 12 | carutapera
# Processing Record 42 of Set 12 | mantua
# Processing Record 43 of Set 12 | gamba
# Processing Record 44 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | campbellsville
# Processing Record 47 of Set 12 | mazagao
# Processing Record 48 of Set 12 | jabinyanah
# Processing Record 49 of Set 12 | nizwa
# Processing Record 50 of Set 12 | yuzhnyy-kospashskiy
# Processing Record 1 of Set 13 | quatre cocos
# Processing Record 2 of Set 13 | lincoln
# Processing Record 3 of Set 13 | espinosa
# Processing Record 4 of Set 13 | brae
# Processing Record 5 of Set 13 | tooele
# Processing Record 6 of Set 13 | sam roi yot
# Processing Record 7 of Set 13 | uige
# Processing Record 8 of Set 13 | sao joao da barra
# Processing Record 9 of Set 13 | marzuq
# Processing Record 10 of Set 13 | cherskiy
# Processing Record 11 of Set 13 | san antonio
# Processing Record 12 of Set 13 | dekar
# Processing Record 13 of Set 13 | novobirilyussy
# Processing Record 14 of Set 13 | keningau
# Processing Record 15 of Set 13 | pocsaj
# Processing Record 16 of Set 13 | saurimo
# Processing Record 17 of Set 13 | uitenhage
# Processing Record 18 of Set 13 | flinders
# Processing Record 19 of Set 13 | igarka
# Processing Record 20 of Set 13 | mokobeng
# Processing Record 21 of Set 13 | whakatane
# Processing Record 22 of Set 13 | cap malheureux
# Processing Record 23 of Set 13 | natalio
# Processing Record 24 of Set 13 | ibanesti
# Processing Record 25 of Set 13 | prince george
# Processing Record 26 of Set 13 | yertsevo
# Processing Record 27 of Set 13 | kajiado
# Processing Record 28 of Set 13 | sigli
# Processing Record 29 of Set 13 | floriano
# Processing Record 30 of Set 13 | karratha
# Processing Record 31 of Set 13 | saint-pierre
# Processing Record 32 of Set 13 | maracaju
# Processing Record 33 of Set 13 | kamenka
# Processing Record 34 of Set 13 | ternate
# Processing Record 35 of Set 13 | san ramon de la nueva oran
# Processing Record 36 of Set 13 | spearfish
# Processing Record 37 of Set 13 | usinsk
# Processing Record 38 of Set 13 | muroto
# Processing Record 39 of Set 13 | la asuncion
# Processing Record 40 of Set 13 | arlit
# Processing Record 41 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 42 of Set 13 | itacare
# Processing Record 43 of Set 13 | sassandra
# Processing Record 44 of Set 13 | sampit
# Processing Record 45 of Set 13 | san clemente
# Processing Record 46 of Set 13 | tukrah
# Processing Record 47 of Set 13 | aginskoye
# Processing Record 48 of Set 13 | asau
# Processing Record 49 of Set 13 | mersing
# Processing Record 50 of Set 13 | nanakuli
# Processing Record 1 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 14 | panaba
# Processing Record 3 of Set 14 | santa cruz de la palma
# Processing Record 4 of Set 14 | cap-aux-meules
# Processing Record 5 of Set 14 | shingu
# Processing Record 6 of Set 14 | skibotn
# Processing Record 7 of Set 14 | honningsvag
# Processing Record 8 of Set 14 | maputo
# Processing Record 9 of Set 14 | santarem
# Processing Record 10 of Set 14 | bilibino
# Processing Record 11 of Set 14 | ponta delgada
# Processing Record 12 of Set 14 | stillwater
# Processing Record 13 of Set 14 | zaysan
# Processing Record 14 of Set 14 | urusha
# Processing Record 15 of Set 14 | ipira
# Processing Record 16 of Set 14 | porto santo
# Processing Record 17 of Set 14 | sorong
# Processing Record 18 of Set 14 | aguilas
# Processing Record 19 of Set 14 | payo
# Processing Record 20 of Set 14 | yuzhne
# Processing Record 21 of Set 14 | nelson bay
# Processing Record 22 of Set 14 | half moon bay
# Processing Record 23 of Set 14 | tevaitoa
# Processing Record 24 of Set 14 | shache
# Processing Record 25 of Set 14 | digby
# Processing Record 26 of Set 14 | cayenne
# Processing Record 27 of Set 14 | dotnuva
# Processing Record 28 of Set 14 | lerwick
# Processing Record 29 of Set 14 | ucluelet
# Processing Record 30 of Set 14 | marystown
# Processing Record 31 of Set 14 | singkang
# Processing Record 32 of Set 14 | umm lajj
# Processing Record 33 of Set 14 | katha
# City not found. Skipping...
# Processing Record 34 of Set 14 | aksu
# Processing Record 35 of Set 14 | portland
# Processing Record 36 of Set 14 | maku
# Processing Record 37 of Set 14 | gold coast
# Processing Record 38 of Set 14 | tuburan
# Processing Record 39 of Set 14 | filingue
# Processing Record 40 of Set 14 | daru
# Processing Record 41 of Set 14 | westerland
# Processing Record 42 of Set 14 | roald
# Processing Record 43 of Set 14 | zlocieniec
# Processing Record 44 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 14 | port macquarie
# Processing Record 46 of Set 14 | boende
# Processing Record 47 of Set 14 | lavrentiya
# Processing Record 48 of Set 14 | porto velho
# Processing Record 49 of Set 14 | bukama
# Processing Record 50 of Set 14 | nyimba
# Processing Record 1 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 15 | labuhan
# Processing Record 3 of Set 15 | limon
# Processing Record 4 of Set 15 | banki
# Processing Record 5 of Set 15 | san aquilino
# Processing Record 6 of Set 15 | kefalos
# Processing Record 7 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 15 | kutum
# Processing Record 9 of Set 15 | markala
# Processing Record 10 of Set 15 | hofn
# Processing Record 11 of Set 15 | tselinnoye
# Processing Record 12 of Set 15 | nauta
# Processing Record 13 of Set 15 | lakes entrance
# Processing Record 14 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 15 | povenets
# Processing Record 16 of Set 15 | baykit
# Processing Record 17 of Set 15 | bahir dar
# Processing Record 18 of Set 15 | corinto
# Processing Record 19 of Set 15 | altay
# Processing Record 20 of Set 15 | dakar
# Processing Record 21 of Set 15 | luangwa
# Processing Record 22 of Set 15 | mandalgovi
# Processing Record 23 of Set 15 | oostburg
# Processing Record 24 of Set 15 | diego de almagro
# Processing Record 25 of Set 15 | northam
# Processing Record 26 of Set 15 | brunsbuttel
# Processing Record 27 of Set 15 | luganville
# Processing Record 28 of Set 15 | celestun
# Processing Record 29 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 15 | yashkul
# Processing Record 31 of Set 15 | pringsewu
# Processing Record 32 of Set 15 | tura
# Processing Record 33 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 15 | richards bay
# Processing Record 35 of Set 15 | palmer
# Processing Record 36 of Set 15 | ryotsu
# Processing Record 37 of Set 15 | joshimath
# Processing Record 38 of Set 15 | lewistown
# Processing Record 39 of Set 15 | whitehorse
# Processing Record 40 of Set 15 | bonavista
# Processing Record 41 of Set 15 | bonthe
# Processing Record 42 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 15 | ugoofaaru
# Processing Record 44 of Set 15 | znamenskoye
# Processing Record 45 of Set 15 | basco
# Processing Record 46 of Set 15 | chicama
# Processing Record 47 of Set 15 | mansa
# Processing Record 48 of Set 15 | san cristobal
# Processing Record 49 of Set 15 | macusani
# Processing Record 50 of Set 15 | palauig
# Processing Record 1 of Set 16 | kalabo
# Processing Record 2 of Set 16 | erenhot
# Processing Record 3 of Set 16 | kaoma
# Processing Record 4 of Set 16 | linxia
# Processing Record 5 of Set 16 | rio gallegos
# Processing Record 6 of Set 16 | fitii
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lebu      CL -37.6167  -73.6500     52.61        91          18
# 1  Umm Kaddadah      SD  13.6017   26.6876     82.94        10           7
# 2          Hilo      US  19.7297 -155.0900     77.29        94         100
# 3    Bredasdorp      ZA -34.5322   20.0403     60.39        91         100
# 4       Kitimat      CA  54.0524 -128.6534     53.98        49          14
# 5        Barrow      US  71.2906 -156.7887      8.62        72           0
# 6         Mapua      NZ -41.2500  173.1000     67.01        52           0
# 7      Coihueco      CL -36.6167  -71.8333     50.74        87          98
# 8        Albany      US  42.6001  -73.9662     40.64        63           7
# 9   Port Alfred      ZA -33.5906   26.8910     60.19        93           6
#
#    Wind Speed   Current Description
# 0        7.83            few clouds
# 1        8.46             clear sky
# 2        5.75  heavy intensity rain
# 3        4.03       overcast clouds
# 4        1.77            few clouds
# 5        8.05             clear sky
# 6        5.06             clear sky
# 7        6.91       overcast clouds
# 8        7.16             clear sky
# 9        1.99             clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
